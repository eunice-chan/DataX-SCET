# %%
import pandas as pd
import random

# %% [markdown]
# Retrieving the datasets

# %%
#a placeholder dataset. In the future this app will scrape the local, daily events of EventBrite.
df = pd.read_csv('LA.csv')
df = df.dropna(subset=['Event Name'])
#the questionaire filled out by users
friends_df = pd.read_csv('friendship_Q')
#pairing table
relationships = pd.read_csv('relationships.csv')

# %% [markdown]
# Cleaning up the datasets

# %%
df['Event Name'] = df['Event Name'].str.lower()
df['Event Description'] = df['Event Description'].str.lower()

df = df[df['Event Name'].notna()]
#removing non-relevant to college students events
df = df[~df['Event Name'].str.contains('kids')]
df = df[~df['Event Name'].str.contains('office')]
df = df[~df['Event Name'].str.contains('teen')]
df = df[~df['Event Name'].str.contains('mtg')]
df = df[~df['Event Name'].str.contains('board')]
df = df[~df['Event Name'].str.contains('meeting')]
df = df[~df['Event Name'].str.contains('child')]
df = df[~df['Event Name'].str.contains('job')]


friends_df = friends_df.fillna(0)

# %% [markdown]
# The events data. In the future this will be retrieved daily from a site like eventbrite.

# %%
df.tail(5)
# Out:
#                                               Event Name  \
# 29468                     computer comfort for beginners
# 29469                     computer comfort for beginners
# 29470                       introduction to the internet
# 29471                                       student zone
# 29472  computer comfort: an internet class for beginners
#
#                                        Event Description Fee Required  \
# 29468  beginners are welcome to come to a free introd...           No
# 29469  learn the basics of internet, email, keyboardi...           No
# 29470  join us at the sun valley library to learn abo...           No
# 29471  students grade 6-12 get access to computers, h...           No
# 29472  learn how to navigate the internet on library ...           No
#
#       Type of Event Subject Matter Age Groupings Event by Service Area  \
# 29468       Library            NaN         Adult                   NaN
# 29469       Library            NaN         Adult                   NaN
# 29470       Library            NaN         Adult                   NaN
# 29471       Library            NaN      Teenager                   NaN
# 29472       Library            NaN         Adult                   NaN
#
#       Event Sponsor  Event Date & Time Start Event Date & Time Ends  ...  \
# 29468       Library  2014-05-01T12:30:00.000                    NaN  ...
# 29469       Library  2014-05-01T12:00:00.000                    NaN  ...
# 29470       Library  2014-05-01T11:30:00.000                    NaN  ...
# 29471       Library  2014-05-01T11:15:00.000                    NaN  ...
# 29472       Library  2014-05-01T10:00:00.000                    NaN  ...
#
#       Elected Official Office Name Elected Officials Name  \
# 29468                          NaN                    NaN
# 29469                          NaN                    NaN
# 29470                          NaN                    NaN
# 29471                          NaN                    NaN
# 29472                          NaN                    NaN
#
#       Neighborhood Council City Reference ID Zip Codes Census Tracts  \
# 29468                  NaN               NaN   18912.0          49.0
# 29469                  NaN               NaN   24030.0         381.0
# 29470                  NaN               NaN   19335.0         165.0
# 29471                  NaN               NaN   23668.0         737.0
# 29472                  NaN               NaN   18513.0         108.0
#
#       Precinct Boundaries LA Specific Plans Council Districts  \
# 29468               222.0               NaN               1.0
# 29469              1364.0               NaN              11.0
# 29470              1249.0               NaN               3.0
# 29471               655.0               7.0              13.0
# 29472              1539.0               NaN               2.0
#
#       Neighborhood Councils (Certified)
# 29468                              47.0
# 29469                              94.0
# 29470                              21.0
# 29471                               NaN
# 29472                              65.0
#
# [5 rows x 26 columns]

# %%
friends_df.tail(5)
# Out:
#               Timestamp First Name Last Name  Age  \
# 23   11/9/2020 11:57:24      Ankur    Chadha   20
# 24   11/9/2020 20:05:48      liona        li   21
# 25  11/10/2020 11:12:53      Kevin       Cao   21
# 26   11/11/2020 7:04:58       Euna        Jo   20
# 27  11/24/2020 15:29:42      Nalin   Dwivedi   19
#
#    When is your preferred time to hang out with friends?   \
# 23               Weekdays at night, Weekends at night
# 24  Weekdays at night, Weekends during the day, We...
# 25  Weekdays at night, Weekends during the day, We...
# 26  Weekdays during the day, Weekdays at night, We...
# 27                                  Weekends at night
#
#    What is your preferred way of spending time with friends?  \
# 23  Doing an activity or exploring, Playing sport,...
# 24  Electronically: messaging, calling, video-chat...
# 25  Grabbing foods or drinks together, Doing an ac...
# 26  Grabbing foods or drinks together, Doing an ac...
# 27  Doing an activity or exploring, Playing sport,...
#
#    How often do you like to spend time with your friends?  \
# 23                                           Everyday
# 24                                   2-3 times a week
# 25                                           Everyday
# 26                                   2-3 times a week
# 27                                   2-3 times a week
#
#    How many people do you like to spend time with at once?  \
# 23                      Small groups (up to 5 people)
# 24                      Small groups (up to 5 people)
# 25                      Small groups (up to 5 people)
# 26                      Small groups (up to 5 people)
# 27                      Small groups (up to 5 people)
#
#    What is your top love language? Favorite movie genre?  ...  \
# 23            Words of Affirmation                     0  ...
# 24                    Quality time                     0  ...
# 25                  Physical touch                     0  ...
# 26                    Quality time                     0  ...
# 27                  Physical touch                     0  ...
#
#     Trivia contests  Virtual escape room  Arts and crafts   Gender  \
# 23              3.0                  2.0               1.0    Male
# 24              3.0                  3.0               3.0  Female
# 25              4.0                  3.0               4.0    Male
# 26              2.0                  2.0               3.0  Female
# 27              5.0                  3.0               3.0    Male
#
#                  Email Address  \
# 23  ankurchadha22@berkeley.edu
# 24       liona.li@berkeley.edu
# 25    caojinghang@berkeley.edu
# 26       eunkyojo@berkeley.edu
# 27  nalin.dwivedi@berkeley.edu
#
#    Any comments on the overall structure of the survey?  \
# 23                                                  0
# 24                                                  0
# 25                                             Bravo!
# 26                                                  0
# 27                                                  0
#
#    Are the questions relevant to qualities you look for in a friend?  \
# 23                                                5.0
# 24                                                3.0
# 25                                                3.0
# 26                                                3.0
# 27                                                3.0
#
#      Any suggestions on question we should be asking?  \
# 23                                                  0
# 24  maybe include some questions about what the pe...
# 25  more personal questions like favorite movie fa...
# 26                                                  0
# 27                                                  0
#
#    What has been your favorite activity recently and why?   \
# 23  Playing tennis because it is a socially distan...
# 24  playing online games (covidopoly, among us) an...
# 25  watching baseball and driving around aimlessly...
# 26                                                  0
# 27                     Playing Among Us with friends!
#
#     What are some virtual activities that you have been enjoying recently?
# 23  Playing video games like 'Among Us' with frien...
# 24                                            games!!
# 25                                     battle Royale?
# 26                                                  0
# 27                                  Among Us, skribbl
#
# [5 rows x 34 columns]

# %%
#converts number to user
def n2u(number):
    return friends_df.iloc[number]

# %% [markdown]
# Dictionary for relating events to features

# %%
event_features_dict = {'active': ['sail', 'run', 'marathon', 'workout', 'yoga', 'hike', 'gym', 'dance' 'swim', 'jog'],
                       'food': ['food', 'cuisine', 'food festival', 'delicious'],
                       'virtual': ['virtual', 'zoom'],
                       'music': ['music', 'band', 'concert'],
                       'draw' : ['paint', 'art', 'photography', 'crafts', 'beads'],
                       'movie' : ['film', 'movie', 'netflix', 'screening'],
                      'brain': ['lecture', 'talk', 'science', 'discussion'],
                      'food': ['tasting', 'drinks', 'delicious', 'restaurant', 'food festival', 'eat', 'dine', 'cooking'],
                      'comedy': ['funny', 'standup', 'stand-up', 'stand up', 'comedy'],
                      'writer': ['author', 'library', 'book', 'poetry', 'writing workshop']}
keys_events = list(event_features_dict.keys())
vals_events = list(event_features_dict.values())

# %%
#helper function that finds out if they will like to do an activity together
def together(user1, user2, str):
    letsdoit = 0
    if (str in friends_df['What is your preferred way of spending time with friends?'].iloc[user1]):
        if (str in friends_df['What is your preferred way of spending time with friends?'].iloc[user2]):
            letsdoit = random.randint(5, 10)
    return letsdoit

# %%
#returns most compatible activity
def most_compat(u1, u2):
    user1 = n2u(u1)
    user2 = n2u(u2)
    
    active = user1['Rank these activities on how much you enjoy them? (5 is most enjoyable) [Hiking]'] + user2['Rank these activities on how much you enjoy them? (5 is most enjoyable) [Hiking]']
    
    draw = user1['Rank these activities on how much you enjoy them? (5 is most enjoyable) [Drawing]'] + user2['Rank these activities on how much you enjoy them? (5 is most enjoyable) [Drawing]']
    brain = user1['Rank these activities on how much you enjoy them? (5 is most enjoyable) [Reading nonfiction]'] + user2['Rank these activities on how much you enjoy them? (5 is most enjoyable) [Reading nonfiction]']
    food = together(u1, u2, 'Grabbing foods or drinks together')
    virtual = together(u1, u2, 'Electronically: messaging, calling, video-chatting, etc.')
    writer = together(u1, u2, 'Rank these activities on how much you enjoy them? (5 is most enjoyable) [Journaling]')
    
    movies = user1['Netflix party'] + user2['Netflix party']
    
    
    dictionary = { 'active' : active, 'draw': draw, 'brain': brain, 'food': food, 'virtual': virtual, 'writer': writer,
                 'movie': movies}
    
    maxy = max(active, draw, brain, food, virtual)
    keys = list(dictionary.keys())
    vals = list(dictionary.values())
    
    #randomly picks from top picks
    
    return keys[vals.index(maxy)]

# %%
#uses most compatible activity and the keywords dictionary to find a suitable activity from event list.
def reccomend_something(u1, u2):
    
    user1 = n2u(u1)
    user2 = n2u(u2)
    
    compatible_activity = most_compat(u1, u2)
    
    
    lw = event_features_dict.get(most_compat(u1, u2))
    new_df = df.copy()
    #new_df = if_in_list(lw, new_df.loc[new_df['Event Name']])
    mask = new_df['Event Name'].apply(lambda x: any(item for item in lw if item in x))
    df1 = df[mask]
    
    ans = df1.sample()[['Event Name']]
    return ans.iloc[0]

# %%
#finds compatible activities for all users in dataset
relationships['Suggested Activity'] = relationships.apply(lambda x: reccomend_something(x['User1'], x['User2']), axis=1)

# %%
relationships= relationships[['User1', 'User2', 'Suggested Activity']]

# %%
relationships.sample(10)
# Out:
#      User1  User2                                 Suggested Activity
# 195     13     14             discussion of world war ii biographies
# 211     15     17  ballet, hip hop, piano, gymnastics, cheerleadi...
# 220     16     21                                  dahn yoga classes
# 194     12     21  return of the creature features! library club ...
# 18       0     19  ballet, hip hop, piano, gymnastics, cheerleadi...
# 32       1     13                                    book discussion
# 177     11     13  ballet, hip hop, piano, gymnastics, cheerleadi...
# 63       3      7  ballet, hip hop, piano, gymnastics, cheerleadi...
# 27       1      8  silver lake nc arts & culture committee 7-12-1...
# 127      7      9       mar vista cc_great streets ad hoc committee_
